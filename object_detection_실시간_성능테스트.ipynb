# %% [markdown]
# <a href="https://colab.research.google.com/github/PowerZolffGirl/Bubbling-Start/blob/main/object_detection_%EC%8B%A4%EC%8B%9C%EA%B0%84_%EC%84%B1%EB%8A%A5%ED%85%8C%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5 
# !pip install -r yolov5/requirements.txt 
# %cd yolov5
 
import torch
from IPython.display import Image, clear_output
 
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%time
# !python detect.py --weights yolov5x.pt --img 1280 --conf 0.4 --source ./FeeltheRhythmofKorea.mp4
# Out:
# ...
# detect: weights=['yolov5x.pt'], source=./FeeltheRhythmofKorea.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
# 100% 166M/166M [00:01<00:00, 96.9MB/s]
#
# Fusing layers...
# Model Summary: 444 layers, 86705005 parameters, 0 gradients
# video 1/1 (1/2221) /content/yolov5/FeeltheRhythmofKorea.mp4: 736x1280 Done. (0.484s)
# video 1/1 (2/2221) /content/yolov5/FeeltheRhythmofKorea.mp4: 736x1280 Done. (0.476s)
# video 1/1 (3/2221) /content/yolov5/FeeltheRhythmofKorea.mp4: 736x1280 Done. (0.481s)
# video 1/1 (4/2221) /content/yolov5/FeeltheRhythmofKorea.mp4: 736x1280 Done. (0.486s)
# ...

# %%
from google.colab import files
files.download('/content/yolov5/runs/detect/exp/FeeltheRhythmofKorea.mp4')

# %%
# !git clone https://git.ffmpeg.org/ffmpeg.git ffmpeg
# Out:
# Cloning into 'ffmpeg'...
# remote: Enumerating objects: 20837, done.
# remote: Counting objects: 100% (20837/20837), done.
# remote: Compressing objects: 100% (7803/7803), done.
# remote: Total 647321 (delta 16949), reused 15797 (delta 13020)
# Receiving objects: 100% (647321/647321), 159.49 MiB | 17.06 MiB/s, done.
# Resolving deltas: 100% (520842/520842), done.

# %%
# !ffmpeg -i '/content/yolov5/10sTestVideo720.mp4' -vf fps=6 image-%d.jpeg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# %%time
# !python detect.py --weights yolov5x.pt --img 1280 --conf 0.4 --source /content/yolov5/dataset
# Out:
# detect: weights=['yolov5x.pt'], source=/content/yolov5/dataset, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86705005 parameters, 0 gradients
# image 1/59 /content/yolov5/dataset/image-1.jpeg: 736x1280 Done. (0.478s)
# image 2/59 /content/yolov5/dataset/image-10.jpeg: 736x1280 2 persons, Done. (0.475s)
# image 3/59 /content/yolov5/dataset/image-11.jpeg: 736x1280 3 persons, Done. (0.491s)
# image 4/59 /content/yolov5/dataset/image-12.jpeg: 736x1280 3 persons, Done. (0.485s)
# ...

# %%
from google.colab import files
files.download('/content/yolov5/runs/detect/exp2')
